# %% [markdown]
# # 머신 러닝을 활용한 의류제품의 판매량 예측 모델 - 아우터웨어 품목을 중심으로 . 논문 정리
#
# ## 출처:[http://www.koreascience.or.kr/article/JAKO202126651473241.pdf](http://www.koreascience.or.kr/article/JAKO202126651473241.pdf)

# %% [markdown]
# # 서론
#
# Liu et al.(2013)은 판매량 예측은 패션 산업에서 매우 중요한
# 문제인 만큼 지금까지 예측방법에 대한 많은 연구가 이루어져
# 왔는데 각각의 방법이 한계점이 있다고 지적하면서 정량적 분석
# 방법을 통계적 방법에 기반한 예측법, AI(Artificial Intelligence)
# 기반 예측법, 다양한 유형의 하이브리드(hybrid) 예측법으로 분
# 류하여 설명하였다. 전통적으로 선형회귀분석(linear regression),
# 이동평균법(moving average), 지수평활법(exponential smoothing),
# 베이즈 분석(bayesian analysis) 등과 같은 다양한 통계기법과
# ARIMA(Auto Regressive Integrated Moving Average)와 SARIMA
# (Seasonal ARIMA)와 같은 시계열분석 통계기법이 이용되어 왔
# 다(Mostard et al., 2011; Thomassey et al., 2003; Yelland &
# Dong, 2014). 통계적 분석 방법은 AI 분석법에 비해 비교적
# 간단하고 컴퓨팅 시간 면에서 빠르게 분석 결과를 확인할 수
# 있으나, AI 기반 분석법보다 예측율이 낮고 특히 패션 판매량
# 은 계절적 요인이나 트렌드 요인 등 많은 외부 변수들의 영향
# 을 받아 불규칙성을 보이므로 만족할 만한 예측성과를 기대하
# 기 어렵다(Liu et al., 2013)
#
# 컴퓨터 기술의 진화로 AI기반 분석법은 예측력을 향상시켰
# 고 인공지능 분석법 중에서 ANN(Artificial Neural Network),
# ENN(Evolutionary Neural Network). 퍼지로직 모델(fuzzy logic
# mode)이 패션 판매예측에 많이 이용되어 왔다(Au et al., 2008;
# Frank et al., 2003; Hui et al., 2005; Sztandera et al., 2004).
# 이와 같은 모델은 전통적인 ARIMA, SARIMA 모델보다 예측
# 력은 우수하지만 분석 플랫폼과 컴퓨팅 파워가 준비되어야 하
# 고 좀 더 시간이 소요되므로 비교적 간단한 머신러닝 기법인
# ELM(Extreme Learning Machine)이나 EELM(Extended ELM)
# 모델이 개발되었다(Sun et al., 2008; Yu et al., 2012). 머신
# 러닝과 인공지능 기반의 예측법도 여전히 완벽한 모델이라 할
# 수 없으므로 패션 판매량 예측을 향상시키기 위하여 다양한 유
# 형의 하이브리드 모델이 시도되고 있는 중이다(Liu et al., 2013).
# 하이브리드 모델이란 다양한 분석기법을 함께 사용하여 예
# 측모델을 개발하는 것인데, 통계분석, 머신러닝, AI 인공신경망
# 의 기법에서 한 가지 분석 기법만 사용하는 것보다 효율성이
# 높은 것으로 나타났다. 그러므로 여러 학자들이 각각의 분석법
# 의 강점을 조합하여 패션 판매량 예측을 위한 새로운 모델을 제안하였는데, Vroman et al.(1998)은 퍼지로직에 근거한 하이
# 브리드 패션 예측모델 개발의 선구자로 지수평활법 중의 하나
# 인 홀트-윈터(Holt-Winter)모델에 퍼지로직을 조합한 분석법을
# 개발하였다. Yesil et al.(2012)도 순수한 통계법과 퍼지로직 모
# 델을 조합한 하이브리드 모델을 개발하여 패스트 패션 예측에
# 적용하였고 예측력이 향상되었다고 설명하였다.

# %% [markdown]
# # Annual Automobile Sales Prediction Using ARIMA Model 논문 정리
#
# ## 출처:[https://gvpress.com/journals/IJHIT/vol10_no6/2.pdf](https://gvpress.com/journals/IJHIT/vol10_no6/2.pdf)

# %% [markdown]
# ## Abstract
#
# Sales forecasting is a most important application in industries and has been one of the
# most scientifically and technologically challenging problems around the world.
#
# One approach of prediction is to spot patterns in the past, when it is known in advance what followed them and verify it on more recent data.
#
# If a pattern is followed by the same outcome frequently enough, it can be concluded that it is a genuine relationship.
#
# Because this approach does not assume any special knowledge or form of the regularities, the
# method is quite general applicable to other series not just climate.
#
# 판매 예측은 산업 분야에서 가장 중요한 부분이며 전 세계에서 가장 과학적이고 기술적으로 도전적인 문제 중 하나였습니다.
#
# 예측의 한 가지 접근 방식은 과거의 패턴을 미리 알려주고 최근의 데이터에서 이를 검증하고 확인하는 것입니다.
#
# 패턴이 똑같은 결과가 자주 충분히 뒤 따르는 경우, 진짜 관계임을 결론 지을 수 있습니다.
#
# 이러한 접근 방식은 특별한 지식이나 규칙의 형태를 취하지 않으므로 이 방법은 뿐만 아니라 기후가 아닌 다른 영역에 적용 할 수 있습니다.
#
# Sales prediction phenomena have many parameters like Number of sales, production, Consumed cost and
# Time required that are impossible to enumerate and measure.
#
# In this paper, we are going to use the ARIMA model for predicting the number of sales for a Time series data.
#
# The dataset tractor sales data for a period of ten years (2003-2014) obtained from the
# Mahindra Tractors Company are used from which use to classify the performance by
# drawing various scattered plots and graphs.
#
# The result of the ARIMA results shows that
# which predicts better for the sales prediction of the next following 5 years.
#
# 판매 예측 현상은 열거하고 측정 할 수 없는 판매, 생산, 소비 비용 및 시간에 필요할 수 있는 많은 매개 변수를 가지고 있습니다.
#
# 이 논문에서는 시계열 데이터의 판매 수를 예측하기 위해 Arima 모델을 사용하려고 합니다.
#
# Mahindra 트랙터 회사에서 얻은 10 년 (2003-2014)의 데이터 세트, 트랙터 판매 데이터는 흩어져있는 플롯과 그래프를 그려서 성능을 분류하는 데 사용되었다.
#
# Arima 결과는 다음 5 년의 판매 예측에 대해 더 잘 예측하는 것을 보여줍니다.

# %% [markdown]
# ## 1. Introduction
#
# Sales prediction is a complex process and a challenging task for researchers.
#
# It includes expertise in multiple disciplines.
#
# The prediction of atmospheric parameters is essential for various applications.
#
# Accurate prediction of Sales parameters is a difficult task due to the dynamic nature of atmosphere. Generally prediction is done on Time series data.
#
# A time series is a sequence of observed values of some entity that is measured at different points
# in time.
#
# With the advancement of collecting data, huge amounts of data have been
# collected making it impossible to be processed manually.
#
# This is where the time series
# analysis has to be automated and take advantage of modern computing mechanisms.
#
#
# 판매 예측은 연구원을 위한 복잡한 프로세스 및 도전적인 작업입니다.
#
# 여기에는 여러 분야의 전문성이 포함됩니다.
#
# 대기 파라미터의 예측은 다양한 응용에 필수적이다.
#
# 판매 매개 변수의 정확한 예측은 대기의 역동적인 특성으로 인해 어려운 작업입니다.
#
# 일반적으로 예측은 시계열 데이터에서 수행됩니다.
#
# 시계열은 다른점에서 측정 된 일부 엔티티의 관찰 된 값의 순서입니다.
#
# 데이터 수집의 발전을 통해 엄청난 양의 데이터가 수집되어 수동으로 처리 할 수 없게 만듭니다.
#
#
# 시계열 분석을 자동화하고 현대적인 컴퓨팅 메커니즘을 이용해야합니다.
#
#
# Various techniques like linear regression, auto regression, Multi-Layer Perceptron,
# Radial Basis Function networks are applied to predict atmospheric parameters like
# temperature, wind speed, rainfall, meteorological pollution etc.
#
#
# In the recent past many forecast methods
# have been developed using Artificial Neural Networks (ANNs).
#
# Neural network
# techniques have the potential to handle complex, nonlinear problems in a better way when
# compared to traditional techniques.
#
# However systems developed using neural network
# model suffer from certain drawbacks like local minima, model over fitting etc
#
# 선형 회귀, 자동 회귀, 다중 레이어 퍼셉트론,방사형 기반 기능 네트워크는 온도, 풍속, 강우량, 기상 오염 등 대기 파라미터를 예측하는 데 적용됩니다.
#
# 최근 과거 많은 예측 방법은 ANN을 사용하여 개발되었다.
#
# 신경망기술은 전통적인 기술에 비해 더 나은 방법으로 복잡하고 비선형 문제를 처리 할 수 있는 잠재력을 가지고 있습니다.
#
# 그러나 신경망을 사용하여 개발 된 시스템모델은 현지 최소치, Model 클래스의 훈련 단계의 특정 단점으로 고통받습니다.

# %% [markdown]
# In this paper we are going use ARIMA model for the predicting the automobile sales.
#
# The performance of ARIMA is compared with SVM and show that which is better for
# predicting the temperature with a short time.
#
# We have collected data set from Jan-2003 to
# Dec-2014 from the Mahindra tractor sales.
#
# Here, we have taken “Number of tractors sold”
# parameter where we are going to apply ARIMA to predict the sales for the next following
# 5 years.
#
# 이 논문에서는 자동차 판매 예측을 위한 ARIMA 모델을 사용하고 있습니다.
#
# ARIMA의 성능은 SVM과 비교해서 짧은 시간에 온도를 예측하는데 더 좋다는 것을 보여줍니다.
#
# 여기서 우리는 "판매 된 트랙터 수" 파라미터를 Arima를 적용 해서 판매 5년 후를 예측하였다.

# %% [markdown]
# ## 2. Literature Survey
#
# The first operational numerical sales prediction model consisted of only one layer and
# therefore it could model only the slight variation of the mean vertical structure of the
# sales.
#
# Computers now permit the development of multilevel (usually about 10–20) models
# that could resolve the vertical variation of the production, consumption, time.
#
# These multilevel models predict the fundamental sales variables for large scales of motion.
#
# M. M. Elkateb et al. (1998) “A comparative study of medium-weather-dependent load
# forecasting using enhanced artificial/fuzzy neural network and statistical techniques”.
#
#
#
# 첫 번째 운영 수치 판매 예측 모델은 하나의 레이어만으로 구성되어 있습니다.
#
# 따라서 그것은 판매 평균 수직 구조의 약간의 변화만을 모델링 할 수 있습니다.
#
#
# 컴퓨터는 이제 생산, 소비, 시간의 수직 변화를 해결할 수 있는 (일반적으로 약 10-20) 다양한 모델의 개발을 허용합니다.
#
# 다중 레벨 모델은 큰 움직임의 크기에 대한 기본 판매 변수를 예측합니다.
#
# M. M. Elkateb et al. (1998) "향상된 인공 / 퍼지 신경망 및 통계 기술을 사용한 예측 ,날씨 의존에 대한 비교 연구 ".
#
#
# First, Minitab statistical software package was
# used for peak load prediction using Autoregressive Integrated Moving Average (ARIMA)
# technique, and an average error value of 11.7% is achieved.
#
# Next, an Artificial Neural
# Network (ANN) was utilized and several suggestions are implemented to build an
# adaptive form of ANN.
#
# Direct ANN implementation shown poor performance.
#
#
# ARIMA를 이용해서 전력망의 최대 수요 예측를 하여 11.7 %의 평균 오차 값이 달성됩니다.
#
# 다음으로 인공 신경네트워크 (ANN)가 활용되었으며 몇 가지 제안 사항이 구현됩니다.

# %% [markdown]
# Raymond Y.C. Tse, (1997) suggested that the following two questions must be
# answered to identify the data series in a time series analysis: (1) whether the data are
# random; and (2) are there any patterns.
#
# This is followed by another three steps of model
# identification, parameter estimation and testing for model validity.
#
# If a series is random,
# the correlation between successive values in a time series is close to zero.
#
# If the
# observations of time series are statistically dependent on each another, then the ARIMA is
# appropriate for the time series analysis.
#
# Meyler et al (1998) drew a framework for ARIMA time series models for forecasting
# Irish inflation.
#
# raymond y.c. TSE, (1997)는 시계열 분석에서 데이터 시리즈를 식별하는 다음 두 가지 질문이 있어야 한다고 제안했다.
#
# (1)데이터가 무작위인지 (2) 패턴이 있는지.
#
# 이것은 모델의 또 다른 3단계가 뒤 따른다, 모델 식별, 모수 추정치 및 모델 평가 테스트.
#
# 시리즈가 무작위 인 경우,시계열의 연속 값 간의 상관 관계는 0에 가깝습니다.
#
#
# * 현실적으로 모집단의 특성, 즉 모수를 아는 것은 거의 불가능하다. 따라서 표본의 특성인 통계량을 통해 모수를 추정(estimation)한다. 따라서 통계량을 모수 추정치(parameter estimate)라고 부르기도 한다.
#
# * Model Validation - 만든 모델이 실제로 사용하기에 적합한지 확인(검증)하는 작업
#
# 시계열의 관측은 서로 통계적으로 의존하면 ARIMA는 시계열 분석에 적합합니다.
#
# Meyler et al (1998)은 Irish 인플레이션 예측을 위한 Arima 시계 시리즈 모델을 위한 프레임 워크를 그렸습니다.

# %% [markdown]
# In their research, they emphasized heavily on optimizing forecast
# performance while focusing more on minimizing out-of-sample forecast errors rather than
# maximizing in-sample ‘goodness of fit’.
#
# In 2000 Toth et al. compared short-term rainfall prediction models for real-time flood
# forecasting.
#
# They applied three time series models, auto-regressive moving average
# (ARMA), ANN and k-nearest-neighbors (KNN) method for forecasting storm rainfall
# occurring in the Sieve River basin, Italy, in the period 1992- 1996 with lead times varying
# from 1 to 6 h.
#
# The result showed that the ANN performed the best in the improvement of
# the runoff forecasting accuracy when the predicted rainfall was used as inputs of the
# rainfall run-off model.
#
# 연구에서 샘플 예측 오류를 최소화하는 데 더 초점을 맞추는데 최적화 예측에 강하게 강조했다.
#
# 2000 년에 et al. 실시간 홍수를 위한 단기 강우 예측 모델에 그들은 ARMA,ANN, KNN 알고리즘을 1992 년, 1996 년 1에서 6 시까지 이탈리아 시브 강 분지에서 발생하는 폭풍우 강우량을 예측하는데 사용하였다.

# %% [markdown]
# Contreras et al (2003) in their study, using ARIMA methodology, provided a method
# to predict next-day electricity prices both for spot markets and long-term contracts for
# mainland Spain and Californian markets.
#
# In, “A comparative analysis for wind speed Prediction”, authors Tarade R.S, Katti P.K
# presented a wind speed predictor based on Autoregressive Integrated Moving Average
# (ARIMA) which is able to predict short term wind speed, which is essential in order to
# prevent systems inaction from the effects of strong winds.
#
# It also helps in using wind
# energy as an alternative source of energy, mainly for electrical power generation.
#
# Wind speed prediction has applications in military and civilian fields for air traffic control,
# rocket launching, ship navigation etc. The mean squared error (MSE) was 3.57.
#
#
# Contreras et al (2003)은 Arima 방법론을 사용하여 방법을 제공합니다.시장 및 장기 계약을 위해 다음날 본토 스페인과 캘리포니아 시장의 전기 가격을 예측하기 위해 방법을 제공합니다.
#
# "풍속 예측을 위한 비교 분석", 저자 Tarade R.S, Katti P.K는 강한 바람의 영향으로부터 시스템이 비 활동을 방지하기 위해서 필수적인 단기 풍속을 예측할 수 있는 ARIMA 알고리즘으로 기반한 풍속 예측기를 제시하였습니다.
#
# 에너지는 주로 전력 생산을 위한 에너지원으로서 사용되는데 도움이 되었습니다.
#
# 풍속 예측에는 로켓 발사, 선박 탐색, 공기 교통 통제를 위한 군대 및 민간 분야의 응용 분야에 활용되었습니다.
#
# 평균 제곱 오차 (MSE)는 3.57이었습니다.
#
# ## 3. Methodology
#
# 3.1. ARIMA: (Auto Regressive Integrated Moving Average)
#
# ARIMA model is done on time series data.
#
# Time series data is a sequence of
# observations collected from a process with equally spaced periods of time.
#
# Examples: Industrial Averages, Daily data on sales, Daily Customers.
# Stages of Time series model process using ARIMA:
#
#
# ## 3. 방법론
#
# 3.1. ARIMA : ARIMA 모델은 시계열 데이터에서 작동됩니다.
#
# 시계열 데이터는 동등하게 나누어진 기간으로 수집 된 관찰된 시퀀스입니다
#
# 예 : 산업 평균, 매일 판매 데이터, 일일 고객. ARIMA를 사용하는 시계열 모델 프로세스의 단계등

# %% [markdown]
# ARIMA is also known as Box-Jenkins approach. To build a time series model issuing
# ARIMA, we need to study the time series and identify p,d,q. Where,
#
# p – Auto Regressive (Auto Correlation)
#
# d - Integrated (Stationary / Trend)
#
# q - Moving Average (Shocks / Error)
#
#  Identification: Determine the appropriate values of p, d, & q using the ACF,
# PACF, and unit root tests. p is the AR order, d is the integration order, q is the MA
# order
#
#  Estimation: Estimate an ARIMA model using values of p, d, & q you think are
# appropriate.
#
#  Diagnostic checking: Check residuals of estimated ARIMA model(s) to see if they
# are white noise; pick best model with well-behaved residuals.
#
# Forecasting: Produce out of sample forecasts or set aside last few data points for in sample forecasting.

# %% [markdown]
# 1. Autoregressive (AR) Process:
#
#
# 2. Moving Average (MA) Process:
#
#
# 3. Stationary Series (Integrated):
#
# In order to model a time series with the Box-Jenkins approach, the series has to be
# stationary. In practical terms, the series is stationary if tends to wonder more or less
# uniformly about some fixed level. In statistical terms, a stationary process is assumed to
# be in a particular state of statistical equilibrium, i.e., p(xt) is the same for all t.
# In order to achieve a series as stationary we need to do Regular differencing (RD),
#
# (1st order) ∇xt = (1 – B)xt = xt – xt-1 (3)
#
# (2nd order) ∇2xt = (1 – B)2xt = xt – 2xt-1 + xt-2 (4)
#
# “B” is the backward shift operator
# It is unlikely that more than two regular differencing would ever be needed

# %% [markdown]
# > ARIMA 알고리즘 최적의 파라미터 찾은 후 밑에 예시 그림과 같이 공식 구현하기(논문작성시)
#
# - 출처:[https://developer-ellen.tistory.com/21](https://developer-ellen.tistory.com/21)

# %%
from IPython.display import Image  # 주피터 노트북에 이미지 삽입
Image("C://Users/MyCom/jupyter-tutorial/Walmart/image/20220319_185315_1.png")

# %% [markdown]
# ## Dataset and Preprocessing
#
# The tractor sales data for a period of ten years (2003-2014) obtained from the
# Mahindra tractors company, from which data is used to build the models and the
# prediction for the next following five years between January and December is obtained by
# the test models.
#
# The database includes readings of several weather parameters recorded at
# every half hour interval.
#
#
# 10 년 (2003-2014)의 트랙터 판매 데이터 Mahindra 트랙터 회사로 부터 얻은 데이터를 사용하여 모델을 구축하는 데 사용되었습니다.
#
# 예측과 모델을 만들기 위해 다음 5 년 동안 기록 된 여러 날씨 매개 변수의 판독 값이 포함됩니다.
#
# 30 분 간격으로 연간 트랙터 판매는 이 데이터베이스에서 추출되어 사용됩니다.
#
#
# The real world databases are highly susceptible to noisy and missing data.
#
# The data can be preprocessed to improve the quality of data and thereby improve the
# prediction results.
#
# In this work, the data taken had applied cleaning and transformation.
#
# Data cleaning fills in the missing values, while data transformation improves the
# accuracy, speed and efficiency of the algorithms used.
#
# The missing value for number of sales in a day is replaced with the mean of number of
# sales for that month while building the SVM model.
#
# The data is normalized using Z-score
# normalization where the values of an attribute A, are normalized based on the mean (Ā)
# and standard deviation (σA) of A.
#
# 실제 데이터베이스는 노이즈와 missing data에 민감합니다.
#
# 데이터는 데이터의 질을 개선하기 위해 전처리 될수 있고 그러므로 예측 결과를 개선할 수 있습니다.
#
# 데이터 정리는 널값으로 채우고 데이터 변환은 사용된 알고리즘의 정확성, 속도 및 효율성을 개선하기 위해 사용됩니다.
#
# 하루에 매출 수에 대한 널값은 SVM 모델을 구축하는 동안 해당 달의 판매의 평균의 수으로 대체됩니다.
#
# 데이터는 속성 A의 값이 표준 편차 (σA),평균 (Â)에 기반하여 정규화되는 Z-Score를 사용하여 정규화됩니다.

# %% [markdown]
# # A comparative study between LSTM and ARIMA for sales forecasting in retail
#
#
# ## 출처: [https://www.diva-portal.org/smash/get/diva2:1214307/FULLTEXT01.pdf](https://www.diva-portal.org/smash/get/diva2:1214307/FULLTEXT01.pdf)

# %% [markdown]
# # auto_arima 후에 할 일: 잔차의 백색 잡음 여부 / 정규성 / 등분산성 확인
#
# ## 출처:[https://assaeunji.github.io/statistics/2021-09-08-arimapdq/](https://assaeunji.github.io/statistics/2021-09-08-arimapdq/)
#
#
# auto_arima의 summary 결과의 Ljung-Box (Q), Jarque-Bera (JB) 등의 검정 통계량을 통해 확인할 수 있고, 혹은 plot_diagnositics() 함수로 잔차를 시각화하여 확인할 수 있습니다.
#
# ARIMA에서 모형이 잘 적합되었다, 이제 손 떠나도 된다의 기준은 무엇일까요?
#
# 바로 모형을 적합하고 남은 잔차 (residuals)가 시간과 무관하게 정상성을 띠면서 (즉, 일정한 평균과 분산을 갖고) 정규성을 만족해야한다는 것입니다. 즉, 아래와 같이 말이죠.
